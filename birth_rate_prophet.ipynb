# %% [markdown]
# <a href="https://colab.research.google.com/github/ElphysAlvarez01/Project1/blob/Priscilla-branch/birth_rate_prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install prophet

# %%
import pandas as pd
import datetime as dt
from prophet import Prophet

# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0f2102fe-c7c0-4bc0-82b5-3c0a586849dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f2102fe-c7c0-4bc0-82b5-3c0a586849dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
birth_rate_df = pd.read_csv("Birth_Rate.csv")
birth_rate_df.head()
# Out:
#          DATE  SPDYNCBRTINUSA
# 0  1960-01-01            23.7
# 1  1961-01-01            23.3
# 2  1962-01-01            22.4
# 3  1963-01-01            21.7
# 4  1964-01-01            21.1

# %%
birth_rate_df = birth_rate_df.rename( columns={"SPDYNCBRTINUSA":"Crude Birth Rate"})

# %%
birth_rate_df['DATE'] = pd.to_datetime(birth_rate_df['DATE'])

# %%
birth_year_df = birth_rate_df[["DATE", "Crude Birth Rate"]]

# %%
birth_year_df.set_index("DATE")
# Out:
#             Crude Birth Rate
# DATE
# 1960-01-01              23.7
# 1961-01-01              23.3
# 1962-01-01              22.4
# 1963-01-01              21.7
# 1964-01-01              21.1
# ...                      ...
# 2017-01-01              11.8
# 2018-01-01              11.6
# 2019-01-01              11.4
# 2020-01-01              10.9
# 2021-01-01              11.0
#
# [62 rows x 1 columns]

# %%
birth_year_df.plot(x="DATE")
# Out:
# <Axes: xlabel='DATE'>

# %%
#Renamed the columns to the Prophet model syntax
birth_year_df.columns = ["ds", "y"]
birth_year_df.tail()
# Out:
#            ds     y
# 57 2017-01-01  11.8
# 58 2018-01-01  11.6
# 59 2019-01-01  11.4
# 60 2020-01-01  10.9
# 61 2021-01-01  11.0

# %%
#Created a prophet model
m = Prophet()

# %%
#Fitting the model
m.fit(birth_year_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpt_63zt0e/n02zdkj3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpt_63zt0e/9_r85g8y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59355', 'data', 'file=/tmp/tmpt_63zt0e/n02zdkj3.json', 'init=/tmp/tmpt_63zt0e/9_r85g8y.json', 'output', 'file=/tmp/tmpt_63zt0e/prophet_model5mtvncer/prophet_model-20240514234332.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:43:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:43:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Forecast one year of weekly future trends data for Canada
future_births = m.make_future_dataframe(periods=20, freq="Y")

# Display the last five rows of the future_canada DataFrame
future_births.tail()
# Out:
#            ds
# 77 2036-12-31
# 78 2037-12-31
# 79 2038-12-31
# 80 2039-12-31
# 81 2040-12-31

# %%
birth_forecast = m.predict(future_births)
birth_forecast.head()
# Out:
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1960-01-01  0.070940   22.351664   23.707366     0.070940     0.070940
# 1 1961-01-01 -0.515578   21.776929   23.110835    -0.515578    -0.515578
# 2 1962-01-01 -1.100494   21.264581   22.537750    -1.100494    -1.100494
# 3 1963-01-01 -1.685409   20.679482   21.954361    -1.685409    -1.685409
# 4 1964-01-01 -2.270324   19.910462   21.319386    -2.270324    -2.270324
#
#    additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0       22.941081             22.941081             22.941081  22.941081
# 1       22.959127             22.959127             22.959127  22.959127
# 2       22.979638             22.979638             22.979638  22.979638
# 3       22.973598             22.973598             22.973598  22.973598
# 4       22.941081             22.941081             22.941081  22.941081
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# ...

# %%
m.plot(birth_forecast)

# %%
birth_forecast.set_index("ds", inplace=True)


birth_forecast[['yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                 yhat  yhat_lower  yhat_upper
# ds
# 2036-12-31  8.659142    7.202075    9.947991
# 2037-12-31  8.415206    6.857764    9.887984
# 2038-12-31  8.145244    6.438619    9.656662
# 2039-12-31  7.849482    5.978275    9.570836
# 2040-12-31  8.023341    6.047544    9.807246

# %%
birth_forecast[['yhat', 'yhat_lower', 'yhat_upper']].iloc[-10:,:].plot()
# Out:
# <Axes: xlabel='ds'>
